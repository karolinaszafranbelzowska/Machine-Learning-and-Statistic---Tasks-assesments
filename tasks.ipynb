# %% [markdown]
# # Machine Learning and Statistic
# -------------------------------------------------------------------------------------------------------------------------------
# #### Karolina Szafran-Belzowska, G00376368
# #### Task assestment - 2020

# %% [markdown]
# ## Task 1:
# Write a Python function called **sqrt2()** that calculates and prints to the screen the square root of 2 to 100 decimal places. Your code should not depend on any module from the standard library1 or otherwise. You shouldresearch the task first and include references and a description of your algorithm.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Square root of 2 is a positive real number whose square is equal to 2. So this is an example of an algebraic number of degree 2. Geometrically the square root of 2 is the length of the diagonal of a square with side length 1, which follows directly from the Pythagorean theorem[3].
# Many methods of calculating the square root of a positive real number S require an initial value. If this value is too far from the actual value of the root, the calculation will be considerably longer. Accordingly, it is highly desirable to have an estimate of this amount, which may even be very inaccurate but simple to derive[1].

# %% [markdown]
# If I want to get the square root of a given number, I will probably use the sqrt() function from the math.h library. But what if I am not able to use this function? Well, here the stairs begin. I have to determine this element on my own. **The Newton-Raphson** method, which is one of the ways to determine the root, comes to my aid.[2]
# The Newton-Raphson method is an iterative algorithm, the task of which is to determine the square root of a real number. However, when using this algorithm, we must take into account the fact that the result does not necessarily have to be accurate. This is due to, among other things, type restrictions in the compiler.
# The Square Roots via Newton’s Method is a classic algorithm that illustrates many of concerns. The algorithm starts with some guess x1 > 0 and computes the sequence of improved guesses[4].

# %% [markdown]
# **Digit by digit determination** is a method of finding successive digits of the square root. It is slower than the Babylonian method, but has several advantages:
# - it is simple for manual calculations;
# - each digit of the determined root is correct, that is, it will not change in the course of further calculations;
# - if the square root has a finite expansion, the algorithm ends after finding the last digit. This can be used to check whether a given integer is a square.
#
# I write the original square root as a decimal. Numbers are written similar to written division and the square root result will be written above the line. Then group the digits of the square root into pairs, starting with a decimal point in both directions. The decimal point will be the position of the decimal point above the line. One digit of the result will appear above each pair of digits below the line.

# %%
from PIL import Image 

#Load the image
img = Image.open('image1.png')

#show the image
img.show()

# %%
# import required libraries
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
img = mpimg.imread('image1.png')
plt.imshow(img)

# %% [markdown]
# ### The Newton's methon to calculate the square root of 2

# %%
# A function sqrt2() to calculate the square root of 2 using Newton's method [5]

def sqrt2(number, number_iters = 500):
    
    a = float(number) # number to get square root of = a
    
    # a = 2
    
    for i in range(number_iters): # iteration number to meet desired accuracy.
        
        number = 0.5 * (number + a / number) # update
        
# x_(n+1) = 0.5 * (x_n +a / x_n)
    
    return number


print(sqrt2(2)) # calling sqrt2 (newton_method) which gives me the square root of 2
# Output: 1.41421356237
# Out:
# 1.414213562373095

# %% [markdown]
# To display the square root of 2 to 100 decimal places I will use the proper format to get enough decimal places.

# %%
b = sqrt2(2)
format(b, '.100f') # to get 100 digits after the decimal point I used '.100f' format[6]
# Out:
# '1.4142135623730949234300169337075203657150268554687500000000000000000000000000000000000000000000000000'

# %% [markdown]
# To check the answer above I will implement math function to see if I got the correct answer[7].

# %% [markdown]
# **Example 1**

# %%
import math # imported math function
print(math.sqrt(2)) # print the square root of 2
# Out:
# 1.4142135623730951

# %% [markdown]
# **Example 2**

# %%
import math
from sympy import sqrt
a = 2
print('The square root of a to 100 decimal places is: ')
print(sqrt(a).evalf(100))
# Out:
# The square root of a to 100 decimal places is:
# 1.414213562373095048801688724209698078569671875376948073176679737990732478462107038850387534327641573

# %% [markdown]
# **Example 3**

# %%
import math
a = 2
root = (format(math.sqrt(a), '.100f'))
print('The square root of a is: ' + repr(root))
# Out:
# The square root of a is: '1.4142135623730951454746218587388284504413604736328125000000000000000000000000000000000000000000000000'

# %% [markdown]
# ### Summary

# %% [markdown]
# The answers are identical in both cases ((The Newton's method and Example1) where the result is not printed with 100 decimal places. The Newton's method and Example 3 are producing those zeros at the end of the numbers. I suppose it's an effect of using the '.100f' format and floating point error.
# The algorithm is producing a periodic decimal expansion (repeated zeros) and I think its a good approximation of ![image.png](attachment:image.png).
# Before I was able to calculate the square root of 2 without using math functions, I started browsing the websites to see how to calculate and get the task done. Started with wikipedia.org first and that was the first page where I found The Newton's method. I decided that the search would stay with this method.

# %% [markdown]
# ### References (task 1):
# [1] https://pl.wikipedia.org/wiki/Metody_obliczania_pierwiastka_kwadratowego 25/10/2020
#
# [2] https://binarnie.pl/metoda-newtona-raphsona/ 25/10/2020
#
# [3] https://pl.wikipedia.org/wiki/Pierwiastek_kwadratowy_z_2 25/10/2020
#
# [4] https://math.mit.edu/~stevenj/18.335/newton-sqrt.pdf 25/10/2020
#
# [5] https://medium.com/@sddkal/newton-square-root-method-in-python-270853e9185d 25/10/2020
#
# [6] https://mkaz.blog/code/python-string-format-cookbook/ 25/10/2020
#
# [7] https://stackoverflow.com/questions/4733173/how-can-i-show-an-irrational-number-to-100-decimal-places-in-python 25/10/2020
#     https://pl.coredump.biz/questions/4733173/how-can-i-show-an-irrational-number-to-100-decimal-places-in-python#4733238 25/10/2020

# %% [markdown]
# =========================================================================================================================

# %% [markdown]
# ## Task 2:

# %% [markdown]
# The **Chi-squared** test for independence is a statistical hypothesis test like a t-test. It is used to analyse whether two categorical variables are independent. The Wikipedia article gives the table below as an example,stating the Chi-squared value based on it is approximately 24.6. Use scipy.stats to verify this value and calculate the associated p value. You should include a short note with references justifying your analysis in a markdown cell.

# %% [markdown]
# ***

# %%
from IPython.display import Image

# %% [markdown]
# ![Image of Yaktocat](https://github.com/karolinaszafranbelzowska/Machine-Learning-and-Statistic---Tasks-assesments/blob/main/image2.png?raw=true)

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# The Chi-square test: x2
# – any test statistic where the test statistic has a chi-square distribution if the theoretical relationship is true. The chi-square test is for testing hypotheses. In other words, the test value is judged by the chi-square distribution. The test most often used in practice. We can use it to test the compliance of both measurable and non-measurable features[8].
# The Chi-Squared test is a statistical hypothesis test that assumes (the null hypothesis) that the observed frequencies for a categorical variable match the expected frequencies for the categorical variable. The test calculates a statistic that has a chi-squared distribution, named for the Greek capital letter Chi (X) pronounced “ki” as in kite. The result of the test is a test statistic that has a chi-squared distribution and can be interpreted to reject or fail to reject the assumption or null hypothesis that the observed and expected frequencies are the same[9].

# %% [markdown]
# **The Pearson’s chi-squared test** for independence can be calculated in Python using the _chi2_contingency() SciPy function_[10].
# The Pearson’s Chi-Square statistical hypothesis is a test for independence between categorical variables. I will perform the test using Python’s SciPy module[11}.

# %%
# import required libraries
from scipy.stats import chi2_contingency # this function computes the chi-square statistic and p-value 
                                         # for the hypothesis test of independence of the observed frequencies in 
                                         # the contingency table observed.   
from scipy.stats import chi2
import numpy as np # to make my code easier to read.
import pandas as pd # for dataframe work.

# %%
table = np.array([[90, 60, 104, 95], # table helps to perform the test.
                 [30, 50, 51, 20], 
                 [30, 40, 45, 35]])
print(table)
# Out:
# [[ 90  60 104  95]
#  [ 30  50  51  20]
#  [ 30  40  45  35]]

# %%
# Create df with table data.
data = {'A':[90, 30, 30, 150], 'B':[60, 50, 40, 150], 'C':[104, 51, 45, 200],
        'D':[95, 20, 35, 150], 'Total':[349, 151, 150, 650]}
df = pd.DataFrame(data,index=['White collar', 'Blue collar', 'No Collar', 'Total'])
df
# Out:
#                 A    B    C    D  Total
# White collar   90   60  104   95    349
# Blue collar    30   50   51   20    151
# No Collar      30   40   45   35    150
# Total         150  150  200  150    650

# %%
stat, p, dof, expected = chi2_contingency(table) # Perform the test. 
                                                 # returns 3 values, the Chi-square statistic (stat), p-value (p) 
                                                 # and degrees of freedom (dof) 

print(f"p-Value: {p}") # p-value
print('dof = %d' % dof ) #degrees of freedom
print(f"Chi-square stat: {stat}\n")

print(expected) # prints a table of expected values
# Out:
# p-Value: 0.0004098425861096696
# dof = 6
# Chi-square stat: 24.5712028585826
#
# [[ 80.53846154  80.53846154 107.38461538  80.53846154]
#  [ 34.84615385  34.84615385  46.46153846  34.84615385]
#  [ 34.61538462  34.61538462  46.15384615  34.61538462]]

# %%
chi2_contingency(table)
# Out:
# (24.5712028585826,
#  0.0004098425861096696,
#  6,
#  array([[ 80.53846154,  80.53846154, 107.38461538,  80.53846154],
#         [ 34.84615385,  34.84615385,  46.46153846,  34.84615385],
#         [ 34.61538462,  34.61538462,  46.15384615,  34.61538462]]))

# %%
alpha = 0.05 # alpha value of 0.05[11]
print("p = " + str(p)) 
if p <= alpha: # interpret p-value 
    print('Dependent (reject H0)') 
else: 
    print('Independent (H0 holds true)')
# Out:
# p = 0.0004098425861096696
# Dependent (reject H0)

# %% [markdown]
# The **alpha** value denotes the probability of erroneously rejecting H0 (the null hypothesis) when it is true. A lower alpha value is chosen in cases where we expect more precision. If the p-value for the test comes out to be strictly greater than the alpha value, then H0 holds true.
# Therefore, I rejet H0, that is, the result is statistically significant[12].

# %% [markdown]
# ### References (task 2):
# [8] https://pl.wikipedia.org/wiki/Test_zgodno%C5%9Bci_chi-kwadrat, 22/11/2020
#
# [9] https://machinelearningmastery.com/chi-squared-test-for-machine-learning/, 22/11/2020
#
# [10] https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.chi2_contingency.html, 22/11/2020
#
# [11] https://www.geeksforgeeks.org/python-pearsons-chi-square-test/, 22/11/2020
#
# [12] https://www.spcforexcel.com/knowledge/basic-statistics/interpretation-alpha-and-p-value, 22/11/2020
#
# [13] https://www.coursera.org/lecture/data-analysis-tools/python-lesson-2-chi-square-test-of-independence-in-practice-MWLEx, 22/11/2020
#
# https://web.microsoftstream.com/video/f19a3bc6-95ba-4b33-9997-ad2209a8c7aa, Ian McaLoughlin - Running a t-test in Python, 2020 [online].

# %% [markdown]
# ========================================================================================================================

# %% [markdown]
# ## Task 3

# %% [markdown]
# The standard deviation of an array of numbers x is calculated using numpy as np.sqrt(np.sum((x - np.mean(x))**2)/len(x)). However, Microsoft Excel has two different versions of the standard deviation calculation, STDEV.P and STDEV.S . The STDEV.P function performs the above calculation but in the STDEV.S calculation the division is by len(x)-1 rather than len(x) . Research these Excel functions, writing a note in a Markdown cell about the difference between them. Then use numpy to perform a simulation demonstrating that the STDEV.S calculation is a better estimate for the standard deviation of a population when performed on a sample. Note that part of this task is to figure out the terminology in the previous sentence.

# %% [markdown]
# ***

# %% [markdown]
# **STDEV.P function**[14] - calculates standard deviation based on the entire population given as arguments (ignores logical values and text).
# The standard deviation is a measure of how widely values are dispersed from the average value (the mean).
# **STDEV.S function**[15] - estimates standard deviation based on a sample (ignores logical values and text in the sample).
# The standard deviation is a measure of how widely values are dispersed from the average value (the mean).

# %% [markdown]
# Population and sample standard deviation
# Standard deviation measures the spread of a data distribution. It measures the typical distance between each data point and the mean.
# The formula we use for standard deviation depends on whether the data is being considered a population of its own, or the data is a sample representing a larger population[16].
# - If the data is being considered a population on its own, we divide by the number of data points, NNN.
# - If the data is a sample from a larger population, we divide by one fewer than the number of data points in the sample, n-1n−1n, minus, 1.

# %%
# import required libraries
import numpy as np # numerical array
import random
import matplotlib.pyplot as plt # plotting
import statistics # describing and summarizing data
import pandas as pd # statistical summary of data frame.

# %%
p = np.random.randint(1,500,50) # Create a population of random integers between 1 and 500, size = 50
p
# Out:
# array([283,  55, 203, 192, 393,  39,   5, 119, 168, 134, 252, 302, 393,
#         31, 107, 104, 459, 321, 468, 464, 323, 331, 368,  73, 339, 280,
#        124,  16, 165, 286, 297,  36, 401, 318, 177,  45, 418, 129, 159,
#        252, 446, 143, 137, 234, 168, 442,  75,  98, 325, 150])

# %%
n = np.size(p)
n
# Out:
# 50

# %%
figure = plt.hist(p, bins=25)
plt.title("Population", fontsize = 20)
plt.show(n)

# %%
# Printing standard deviation [17]
print("The standard deviation of population (p) is % s " 
                % (statistics.stdev(p))) 
# variance is approximately the squared result of what stdev is.
print("Variance of the population is % s" 
     %(statistics.variance(p)))
# Out:
# The standard deviation of population (p) is 137.42634390829147
# Variance of the population is 18886

# %%
sd_p = np.std(p)
print("(STDEV.P) The standard deviation of the population is", sd_p)
# Out:
# (STDEV.P)The standard deviation of the population is 136.0463759164499

# %%
# Take a sample of 20 from the population 
p[0:20] 
sample = p[0:20]
sample
# Out:
# array([283,  55, 203, 192, 393,  39,   5, 119, 168, 134, 252, 302, 393,
#         31, 107, 104, 459, 321, 468, 464])

# %%
figure = plt.hist(sample, bins=25)
plt.title("Sample of population", fontsize = 20)
plt.show()

# %%
sd_sample = np.std(sample)
print("The standard deviation of sample of population is", sd_sample)
# Out:
# The standard deviation of sample of population is 149.84071542808383

# %%
# standard deviation of sample using a sample of data
s_sample = np.std(sample,ddof=1) # With this implementation, I can use ddof=0 to calculate the standard deviation 
                                  # of a population, or I can use ddof=1 to estimate the standard deviation 
                                  # of a population using a sample of data[18].
print("(STDEV.S) The standard deviation of a population using a sample of data", s_sample)
# Out:
# (STDEV.S) The standard deviation of a population using a sample of data 153.73333029016598

# %%
df = pd.DataFrame(sample)
print (df.describe())
# Out:
#                0
# count   20.00000
# mean   224.60000
# std    153.73333
# min      5.00000
# 25%    106.25000
# 50%    197.50000
# 75%    339.00000
# max    468.00000

# %% [markdown]
# The plot shows the distribution of 20 numbers in the array. The describe() method confirms my earlier calculations.
# Excel's STDEV calculates the sample standard deviation, while NumPy's std calculates the population standard deviation by default.
# np.std(sample, ddof=1) calculates the standard deviation of s using the sample variance (i.e. dividing by n-1 rather than n.).
# STDEV calculates an estimate of the population's standard deviation based on the sample, while STDEV.P calculates the sample's standard deviation, which is the population (if the sample is the whole population).

# %% [markdown]
# ### References (task 3):
# ***
#
# [14] https://support.microsoft.com/en-us/office/stdev-p-function-6e917c05-31a0-496f-ade7-4f4e7462f285, 22/11/2020
#
# [15] https://support.microsoft.com/en-us/office/stdev-s-function-7d69cf97-0c1f-4acf-be27-f3e83904cc23, 22/11/2020
#
# [16] https://www.khanacademy.org/math/statistics-probability/summarizing-quantitative-data/variance-standard-deviation-sample/a/population-and-sample-standard-deviation-review, 27/11/2020
#
# [17] https://www.geeksforgeeks.org/python-statistics-stdev/, 27/11/2020
#
# [18] https://stackabuse.com/calculating-variance-and-standard-deviation-in-python/, 27/11/2020
#
# [19] https://realpython.com/python-statistics/, 11/12/2020

# %% [markdown]
# ## Task 4

# %% [markdown]
# Use scikit-learn to apply k-means clustering to
# Fisher’s famous Iris data set. You will easily obtain a copy of the data set online. Explain in a Markdown cell how your code works and how accurate it might
# be, and then explain how your model could be used to make predictions of species of iris.

# %% [markdown]
# ***

# %% [markdown]
# **Scikit-learn** features various classification, regression and clustering algorithms including support vector machines, random forests, gradient boosting, k-means and DBSCAN, and is designed to interoperate with the Python numerical and scientific libraries NumPy and SciPy.[20]
#
# Scikit-learn, Machine Learning in Python is[21]:
# - Simple and efficient tools for predictive data analysis
# - Accessible to everybody, and reusable in various contexts
# - Built on NumPy, SciPy, and matplotlib
# - Open source, commercially usable - BSD license
#
# **k-means clustering** is a method of vector quantization, originally from signal processing, that aims to partition *n* observations into *k* clusters in which each observation belongs to the cluster with the nearest mean.
# The algorithm has a loose relationship to the k-nearest neighbor classifier, a popular machine learning technique for classification that is often confused with k-means due to the name. Applying the 1-nearest neighbor classifier to the cluster centers obtained by k-means classifies new data into the existing clusters. This is known as nearest centroid classifier or Rocchio algorithm.[22]
# The k-means clustering method is an unsupervised machine learning technique used to identify clusters of data objects in a dataset. There are many different types of clustering methods, but k-means is one of the oldest and most approachable.[23]
# *Random state* in Kmeans function of sklearn mainly helps to start with same random data point as centroid if you use Kmeans++ for initializing centroids. The number of clusters (*n_clusters*) is to form as well as the number of centroids to generate.

# %%
# import the libraries needed in this task
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import datasets

# %%
# get the Iris data from my repository, use pandas package [24]
iris = pd.read_csv('https://raw.githubusercontent.com/karolinaszafranbelzowska/Machine-Learning-and-Statistic---Tasks-assesments/main/iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# data broken down by species. Use seaborn to describe the data [25]
iris = sns.load_dataset("iris")
iris.groupby('species').describe().T
# Out:
# species                setosa  versicolor  virginica
# sepal_length count  50.000000   50.000000  50.000000
#              mean    5.006000    5.936000   6.588000
#              std     0.352490    0.516171   0.635880
#              min     4.300000    4.900000   4.900000
#              25%     4.800000    5.600000   6.225000
#              50%     5.000000    5.900000   6.500000
#              75%     5.200000    6.300000   6.900000
#              max     5.800000    7.000000   7.900000
# sepal_width  count  50.000000   50.000000  50.000000
#              mean    3.428000    2.770000   2.974000
#              std     0.379064    0.313798   0.322497
#              min     2.300000    2.000000   2.200000
#              25%     3.200000    2.525000   2.800000
#              50%     3.400000    2.800000   3.000000
#              75%     3.675000    3.000000   3.175000
#              max     4.400000    3.400000   3.800000
# petal_length count  50.000000   50.000000  50.000000
# ...

# %%
sns.pairplot(iris, hue="species")

# %%
# Summary of data 
summary = iris.describe()
summary = summary.transpose()
print(summary.head())
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %%
iris = datasets.load_iris() # load the Iris data without Species, if you print 'iris' it will be the same as before. 
                            # This Data is better to define target and predictors.
# iris

# %%
# define target and predictors.
X = iris.data[:,[0, 1]] # SepalLengthCm and SepalWidthCm
y = iris.target
print('Labels:', np.unique(y))
# Out:
# Labels: [0 1 2]

# %%
# data through a scatter plot
plt.scatter(X[:,0], X[:,1], c=y, cmap='rainbow')
plt.xlabel('Sepal Length', fontsize=20)
plt.ylabel('Sepal Width', fontsize=20)
# Out:
# Text(0, 0.5, 'Sepal Width')

# %%
P = iris.data[:,[2, 3]] # PetalLengthCm and PetalWidthCm
plt.scatter(P[:,0], P[:,1], c=y, cmap='rainbow')
plt.xlabel('Petal Length', fontsize=20)
plt.ylabel('Petal Width', fontsize=20)
# Out:
# Text(0, 0.5, 'Petal Width')

# %%
# instantiate and fit Kmeans cluster model. I am going to use 3 clusters and a random_state of 0.
# random_state controls the random number generator used and n_clusters observations from data for the initial centroids.
km = KMeans(n_clusters = 3, random_state=0).fit(X) # random initialization of centroids and fit
# km.fit(X)

# %%
# find the center points of the data.
center = km.cluster_centers_
print(center)
# Out:
# [[5.006      3.428     ]
#  [6.81276596 3.07446809]
#  [5.77358491 2.69245283]]

# %% [markdown]
# #### Sepal length and Sepal width

# %%
# define new_labels to find out which cluster does the data observations belong. labels are used in comparison plot.
new_labels = km.labels_

# %%
# plots of actual and predicted for comparison [26]
# Code taken from: https://medium.com/@belen.sanchez27/predicting-iris-flower-species-with-k-means-clustering-in-python-f6e46806aaee, 11/12/2020

fig, axes = plt.subplots(1, 2, figsize=(10,6))
axes[0].scatter(X[:, 0], X[:, 1], c = y, cmap = 'rainbow', edgecolor='k', s=150)
axes[1].scatter(X[:, 0], X[:, 1], c = new_labels, cmap = 'gnuplot', edgecolor='k', s=150)
axes[0].set_xlabel('Sepal length', fontsize=15)
axes[0].set_ylabel('Sepal width', fontsize=15)
axes[1].set_xlabel('Sepal length', fontsize=15)
axes[1].set_ylabel('Sepal width', fontsize=15)
axes[0].tick_params(direction='in', length=10, width=5, colors='k', labelsize=15)
axes[1].tick_params(direction='in', length=10, width=5, colors='k', labelsize=15)
# Define the title
axes[0].set_title('Actual', fontsize=18)
axes[1].set_title('Predicted', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Predicted')

# %% [markdown]
# #### Petal length and Petal width

# %%
# plot of petal length versus petal width
P = iris.data[:,[2, 3]] 
# plt.scatter(P[:,0], P[:,1], c=y, cmap='rainbow')
# plt.xlabel('Petal Length', fontsize=20)
# plt.ylabel('Petal Width', fontsize=20)

# %%
# Plots of actual and predicted for comparison
fig, axes = plt.subplots(1, 2, figsize=(10,6))
axes[0].scatter(P[:, 0], P[:, 1], c = y, cmap = 'rainbow', edgecolor='k', s=150)
axes[1].scatter(P[:, 0], P[:, 1], c = new_labels, cmap = 'gnuplot', edgecolor='k', s=150)
axes[0].set_xlabel('Petal length', fontsize=15)
axes[0].set_ylabel('Petal width', fontsize=15)
axes[1].set_xlabel('Petal length', fontsize=15)
axes[1].set_ylabel('Petal width', fontsize=15)
axes[0].tick_params(direction='in', length=10, width=5, colors='k', labelsize=15)
axes[1].tick_params(direction='in', length=10, width=5, colors='k', labelsize=15)
# Define the title
axes[0].set_title('Actual', fontsize=18)
axes[1].set_title('Predicted', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Predicted')

# %% [markdown]
# #### Petal length and Sepal length

# %%
# plot of petal length versus sepal lentgh
L = iris.data[:,[2, 0]] 
# plt.scatter(L[:,0], L[:,1], c=y, cmap='rainbow')
# plt.xlabel('Petal Length', fontsize=20)
# plt.ylabel('Sepal Length', fontsize=20)

# %%
# Plots of actual and predicted for comparison
fig, axes = plt.subplots(1, 2, figsize=(10,6))
axes[0].scatter(L[:, 0], L[:, 1], c = y, cmap = 'rainbow', edgecolor='k', s=150)
axes[1].scatter(L[:, 0], L[:, 1], c = new_labels, cmap = 'gnuplot', edgecolor='k', s=150)
axes[0].set_xlabel('Petal length', fontsize=15)
axes[0].set_ylabel('Sepal width', fontsize=15)
axes[1].set_xlabel('Petal length', fontsize=15)
axes[1].set_ylabel('Sepal width', fontsize=15)
axes[0].tick_params(direction='in', length=10, width=5, colors='k', labelsize=15)
axes[1].tick_params(direction='in', length=10, width=5, colors='k', labelsize=15)
# Define the title
axes[0].set_title('Actual', fontsize=18)
axes[1].set_title('Predicted', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Predicted')

# %% [markdown]
# #### Sepal width and Petal width

# %%
# plot of sepal width versus petal width
W = iris.data[:,[1, 3]] 
# plt.scatter(W[:,0], W[:,1], c=y, cmap='rainbow')
# plt.xlabel('Petal Length', fontsize=20)
# plt.ylabel('Sepal Length', fontsize=20)

# %%
# Plots of actual and predicted for comparison
fig, axes = plt.subplots(1, 2, figsize=(10,6))
axes[0].scatter(W[:, 0], W[:, 1], c = y, cmap = 'rainbow', edgecolor='k', s=150)
axes[1].scatter(W[:, 0], W[:, 1], c = new_labels, cmap = 'gnuplot', edgecolor='k', s=150)
axes[0].set_xlabel('Petal length', fontsize=15)
axes[0].set_ylabel('Sepal length', fontsize=15)
axes[1].set_xlabel('Petal length', fontsize=15)
axes[1].set_ylabel('Sepal length', fontsize=15)
axes[0].tick_params(direction='in', length=10, width=5, colors='k', labelsize=15)
axes[1].tick_params(direction='in', length=10, width=5, colors='k', labelsize=15)
# Define the title
axes[0].set_title('Actual', fontsize=18)
axes[1].set_title('Predicted', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Predicted')

# %% [markdown]
# K-means clustering is one of the most popular clustering algorithms to solve clustering tasks and get an idea of the structure of the dataset. The goal of k-means is to group data points into distinct non-overlapping subgroups. K-means gives more weight to the bigger clusters. It doesn’t learn the number of clusters from the data and requires to be pre-defined, so you need to decide on the number of clusters. ,
# K-means assumes spherical shapes of clusters and does not work well when clusters are in different shapes such as elliptical clusters.[27]

# %% [markdown]
# ### References (task 4)
# ***
# [20] https://en.wikipedia.org/wiki/Scikit-learn, 11/12/2020
#
# [21] https://scikit-learn.org/stable/, 11/12/2020
#
# [22] https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html, 11/12/2020
#
# [23] https://en.wikipedia.org/wiki/K-means_clustering, 11/12/2020
#
# [24] https://pandas.pydata.org/docs/getting_started/overview.html, 11/12/2020
#
# [23] https://realpython.com/k-means-clustering-python/, 11/12/2020
#
# [24] https://datascience.stackexchange.com/questions/37435/i-got-the-following-error-dataframe-object-has-no-attribute-data, 11/12/2020
#
# [25] https://akshay-a.medium.com/descriptive-statistics-with-pandas-on-iris-data-beginner-bbc4422597ea, 11/12/2020
#
# [26] https://medium.com/@belen.sanchez27/predicting-iris-flower-species-with-k-means-clustering-in-python-f6e46806aaee, 11/12/2020
#
# [27] https://towardsdatascience.com/k-means-clustering-algorithm-applications-evaluation-methods-and-drawbacks-aa03e644b48a, 13/12/2020
#
# Also viewed:
#
# https://www.kaggle.com/prakharrathi25/100-accuracy-classification-in-iris-dataset, 11/12/2020
#
# https://www.datacamp.com/community/tutorials/introduction-machine-learning-python, 11/12/2020
#
# http://www.lac.inpe.br/~rafael.santos/Docs/CAP394/WholeStory-Iris.html, 11/12/2020
#
# https://www.datacamp.com/community/tutorials/introduction-machine-learning-python, 11/12/2020

# %% [markdown]
# ### END
# ***
